# %%
import pandas as pd
import json
import requests
from urllib import parse
import xmltodict

# %%
url = 'http://apis.data.go.kr/B552657/ErmctInfoInqireService/getStrmBassInfoInqire'
key = 'qIlLlTZnU9ipgBO8frY4eIlcT5n%2BeoMENWFJFtdpD0oWo7kG4nEtn5eyxLs50fBoULGJMSW2oDPXQxgyyMurtQ%3D%3D'

queryParams = f'?{parse.quote_plus("serviceKey")}={key}&' + parse.urlencode({
parse.quote_plus("pageNo"): 1,
})

# xml로 받아온 response
response = requests.get(url + queryParams).text
# xmltodict로 dictionary형태로 바꿔줌
jsonString = json.dumps(xmltodict.parse(response), indent=4)
# dictiondary to json
dic = json.loads(jsonString)

body = dic['response']['body']['items']['item']
dataframe = pd.json_normalize(body)
dataframe
# Out:
#                                           dgidIdName  \
# 0  가정의학과,구강내과,내과,마취통증의학과,방사선종양학과,병리과,보건(의료원)소,비뇨기...
# 1  가정의학과,내과,마취통증의학과,방사선종양학과,병리과,보건(의료원)소,비뇨기과,산부인...
# 2  가정의학과,결핵과,내과,마취통증의학과,방사선종양학과,병리과,비뇨기과,산부인과,성형외...
# 3  가정의학과,내과,마취통증의학과,병리과,비뇨기과,산부인과,소아청소년과,신경과,신경외과...
# 4  가정의학과,구강내과,구강악안면방사선과,내과,마취통증의학과,방사선종양학과,병리과,보건...
# 5  가정의학과,구강내과,내과,마취통증의학과,방사선종양학과,병리과,비뇨기과,산부인과,성형...
# 6  가정의학과,내과,마취통증의학과,방사선종양학과,병리과,비뇨기과,산부인과,성형외과,소아...
# 7  가정의학과,내과,마취통증의학과,방사선종양학과,병리과,보건(의료원)소,비뇨기과,산부인...
# 8  가정의학과,내과,마취통증의학과,방사선종양학과,병리과,보건(의료원)소,비뇨기과,산부인...
# 9  가정의학과,내과,마취통증의학과,방사선종양학과,병리과,비뇨기과,산부인과,성형외과,소아...
#
#                                     dutyAddr dutyEryn dutyHano dutyHayn  \
# 0                   부산광역시 서구 구덕로 179 (아미동1가)        1     1191        1
# 1           울산광역시 동구 대학병원로 25, 울산대학교병원 (전하동)        1      998        1
# 2                   서울특별시 중구 을지로 245 (을지로6가)        1      603        1
# 3                      전라남도 목포시 영산로 483 (상동)        1      577        1
# 4          대구광역시 중구 동덕로 130 (삼덕동2가, 경북대학교병원)        1      914        1
# 5                      경상북도 안동시 앙실로 11 (수상동)        1     1052        1
# 6                      전라북도 익산시 무왕로 895 (신동)        1      795        1
# 7                      경상남도 진주시 강남로 79 (칠암동)        1      899        1
# 8                     대전광역시 서구 둔산서로 95 (둔산동)        1      700        1
# 9  충청남도 천안시 동남구 망향로 201 (안서동, 단국대학교의과대학부속병원)        1      895        1
#
#               dutyMapimg           dutyName      dutyTel1      dutyTel3  \
# 0       1호선 토성역 4, 6번 출구            부산대학교병원  051-240-7000  051-240-7776
# 1                    NaN  학교법인울산공업학원울산대학교병원  052-250-7000  052-250-7000
# 2  동대문역사문화공원역 13번출구 도보5분            국립중앙의료원    0222607114  02-2260-7414
# 3              목포 터미널 근처             목포한국병원  061-270-5500  061-270-5666
# 4                    NaN            경북대학교병원  053-200-5114  053-200-5100
# 5                    NaN           의료법인안동병원  054-840-1004  054-840-0119
# 6                    NaN            원광대학교병원  063-859-1114  063-859-1165
# 7           진주고속버스터미널 부근          경상국립대학교병원  055-750-8000  055-750-8282
# 8                    NaN  학교법인을지학원대전을지대학교병원  042-611-3000  042-259-1119
# 9                    NaN      단국대학교의과대학부속병원  041-550-7114  041-550-6840
#
#   dutyTime1c  ... postCdn2            wgs84Lat            wgs84Lon hpccuyn  \
# 0       1730  ...       41   35.10105418267188  129.01922207984205     NaN
# 1       1730  ...       33       35.5200593154      129.4288047478       2
# 2       1700  ...       64   37.56733955813183  127.00579539705472     NaN
# 3       1800  ...       43    34.8092145829474   126.4163391650001     NaN
# 4       1800  ...       44  35.866235497221617  128.60431466100362      10
# 5       1700  ...       43   36.54691448006022  128.70097021920307     NaN
# 6       1700  ...       38    35.9642419612473    126.959306346821     NaN
# 7       1700  ...       27  35.176340165507916  128.09564813723503     NaN
# 8       1730  ...       33  36.355068712678154  127.38199955857135     NaN
# 9       1700  ...       16   36.84295215169462  127.17327537305154     NaN
#
#   hvccc                                            dutyInf dutyTime6c  \
# 0   NaN                                                NaN        NaN
# 1     0                                                NaN        NaN
# 2   NaN  외래 30분전 접수마감/토요일은 일부과만 진료하며, 진료과 사정상 토요진료가 어려울...       1200
# 3   NaN                                                NaN       1230
# 4     1                                                NaN        NaN
# 5   NaN                                                NaN       1230
# 6   NaN                                                NaN        NaN
# 7   NaN                                           외국인 통역가능        NaN
# 8   NaN                                                NaN       1230
# 9   NaN                           권역외상센터/신생아 집중치료/충남광역치매센터       1230
#
#   dutyTime6s hpcuyn hvcc
# 0        NaN    NaN  NaN
# 1        NaN    NaN  NaN
# 2       0830    NaN  NaN
# 3       0830    NaN  NaN
# 4        NaN      8    0
# 5       0830    NaN  NaN
# 6        NaN    NaN  NaN
# 7        NaN    NaN  NaN
# 8       0830    NaN  NaN
# 9       0900    NaN  NaN
#
# [10 rows x 54 columns]

# %%
url = 'http://apis.data.go.kr/B552657/ErmctInfoInqireService/getStrmBassInfoInqire'
key = 'qIlLlTZnU9ipgBO8frY4eIlcT5n%2BeoMENWFJFtdpD0oWo7kG4nEtn5eyxLs50fBoULGJMSW2oDPXQxgyyMurtQ%3D%3D'

queryParams = f'?{parse.quote_plus("serviceKey")}={key}&' + parse.urlencode({
parse.quote_plus("pageNo"): 2,
})

# xml로 받아온 response
response = requests.get(url + queryParams).text
# xmltodict로 dictionary형태로 바꿔줌
jsonString = json.dumps(xmltodict.parse(response), indent=4)
# dictiondary to json
dic = json.loads(jsonString)

body = dic['response']['body']['items']['item']
dataframe1 = pd.json_normalize(body)
dataframe1
# Out:
#                                  dutyAddr dutyEryn dutyHano dutyHayn  \
# 0   충청북도 청주시 서원구 1순환로 776-0 (개신동,충북대학교병원)        1      792        1
# 1  인천광역시 남동구 남동대로774번길 21 (구월동, 가천대학교길병원)        1     1450        1
# 2                    광주광역시 동구 제봉로 42 (학동)        1     1080        1
# 3              경기도 수원시 영통구 월드컵로 164 (원천동)        1     1168        1
# 4         경기도 의정부시 천보로 271, 의정부성모병원 (금오동)        1      707        1
# 5                    강원도 원주시 일산로 20 (일산동)        1      866        1
# 6                 서울특별시 종로구 대학로 101 (연건동)        1     1758        1
# 7     서울특별시 구로구 구로동로 148, 고려대부속구로병원 (구로동)        1     1228        1
# 8        서울특별시 성북구 고려대로 73, 고려대병원 (안암동5가)        1     1055        1
# 9         제주특별자치도 제주시 도령로 65-  (연동, (연동))        1      531        1
#
#                                    dutyInf                dutyName  \
# 0                         외국인환자유치사업 등록유치기관                 충북대학교병원
# 1                                      NaN          의료법인 길의료재단 길병원
# 2                                      NaN                 전남대학교병원
# 3                                      NaN                 아주대학교병원
# 4                                      NaN           가톨릭대학교의정부성모병원
# 5                                      NaN         연세대학교원주세브란스기독병원
# 6  서울대학교병원 치과진료는 서울대학교 치과병원에 문의 및 별도 접수 필요                 서울대학교병원
# 7                                      NaN         고려대학교의과대학부속구로병원
# 8                                      NaN  (학)고려대학교의과대학부속병원(안암병원)
# 9                                      NaN                  제주한라병원
#
#        dutyTel1      dutyTel3 dutyTime1c dutyTime1s  ... postCdn1 postCdn2  \
# 0     1533-0075  043-269-6114       1700       0900  ...      286       44
# 1  032-460-3548  032-460-3012       1700       0800  ...      215       65
# 2  062-220-5893  062-220-6801       1800       0900  ...      614       69
# 3  031-219-5114  031-219-7700       1700       0900  ...      164       99
# 4     1661-7500  031-820-5200       1700       0830  ...      117       65
# 5  033-741-0114  033-741-1641       1730       0830  ...      264       26
# 6     1588-5700  02-2072-2475       1800       0800  ...      030       80
# 7  02-2626-1114  02-2626-1550       1730       0900  ...      083       08
# 8     1577-0083   02-920-5374       1730       0900  ...      028       41
# 9  064-740-5000  064-740-5158       1700       0900  ...      000       00
#
#              wgs84Lat            wgs84Lon  \
# 0  36.624166824834546   127.4614360502226
# 1   37.45208024654252  126.70916173607195
# 2  35.141852541291165  126.92158688926376
# 3    37.2794477573662  127.04752107106702
# 4   37.75865547828227  127.07767290194454
# 5   37.34795543031888   127.9456453098751
# 6   37.57966608924356  126.99896308412191
# 7   37.49211114525054   126.8847449363546
# 8   37.58715608002366  127.02647086385966
# 9  33.489946745300735  126.48507635686154
#
#                                           dgidIdName  \
# 0                                                NaN
# 1  가정의학과,내과,마취통증의학과,방사선종양학과,병리과,보건(의료원)소,비뇨기과,산부인...
# 2  가정의학과,내과,마취통증의학과,방사선종양학과,병리과,비뇨기과,산부인과,성형외과,소아...
# 3  가정의학과,내과,마취통증의학과,방사선종양학과,병리과,보건(의료원)소,비뇨기과,산부인...
# 4  가정의학과,내과,마취통증의학과,방사선종양학과,병리과,보건(의료원)소,비뇨기과,산부인...
# 5  가정의학과,구강악안면외과,내과,마취통증의학과,방사선종양학과,병리과,비뇨기과,산부인과...
# 6  가정의학과,내과,마취통증의학과,방사선종양학과,병리과,비뇨기과,산부인과,성형외과,소아...
# 7  가정의학과,내과,마취통증의학과,방사선종양학과,병리과,보건(의료원)소,비뇨기과,산부인...
# 8  가정의학과,내과,마취통증의학과,방사선종양학과,병리과,보건(의료원)소,비뇨기과,산부인...
# 9  가정의학과,내과,마취통증의학과,방사선종양학과,병리과,비뇨기과,산부인과,성형외과,소아...
#
#                       dutyMapimg dutyTime6c dutyTime6s hpccuyn hvccc
# 0                            NaN        NaN        NaN     NaN   NaN
# 1                     길병원 사거리 인근       1200       0800       4     0
# 2                            NaN        NaN        NaN     NaN   NaN
# 3                        아주대학교 옆        NaN        NaN      11     2
# 4                            NaN       1200       0830     NaN   NaN
# 5                            NaN        NaN        NaN     NaN   NaN
# 6                      혜화역 3번 출구       1330       0800       8     0
# 7                        구로구청 인근       1200       0900     NaN   NaN
# 8  지하철 6호선 안암역 하차 후 1번출구 도보 500m       1200       0900     NaN   NaN
# 9                            NaN       1200       0900     NaN   NaN
#
# [10 rows x 54 columns]

# %%
df = pd.concat([dataframe, dataframe1])

# %%
df.to_csv('외상센터.csv', encoding = 'utf-8-sig')
