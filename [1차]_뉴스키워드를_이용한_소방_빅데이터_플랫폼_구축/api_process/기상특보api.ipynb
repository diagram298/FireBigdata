# %%
import pandas as pd
import json
import requests
from urllib import parse
import xmltodict

# %% [markdown]
# 우선적으로 수도권기상청 중 서울만 진행
# parse.quote_plus("stnId"):
# 동두천 : 88, 파주 : 99, 백령도 : 102, 서울 : 108, 인천 : 112, 수원 : 119, 양평 : 202, 이천 : 203

# %% [markdown]
# 기상특보목록조회

# %%
url = 'http://apis.data.go.kr/1360000/WthrWrnInfoService/getWthrWrnList'
key = 'buNPq8BZdGw2p%2B3l2B7IMBy3e9PX5fahBKLPiW518y4yMZsQFDJeQW9fpNMb2nt7Xu6j4vz6txHwT5%2BrcFrwhA%3D%3D'

queryParams = f'?{parse.quote_plus("serviceKey")}={key}&' + parse.urlencode({
parse.quote_plus("numOfRows"): 999,
parse.quote_plus("pageNo"): 1,
parse.quote_plus("stnId"): 108,
parse.quote_plus("fromTmFc"): 20221216,
parse.quote_plus("toTmFc"): 20221222,
})

# xml로 받아온 response
response = requests.get(url + queryParams).text
# xmltodict로 dictionary형태로 바꿔줌
jsonString = json.dumps(xmltodict.parse(response), indent=4)
# dictiondary to json
dic = json.loads(jsonString)
dic
body = dic['response']['body']['items']['item']

df = pd.json_normalize(body)
df
# Out:
#     stnId                                              title          tmFc  \
# 0     108  [특보] 제12-235호 : 2022.12.22.18:00 / 풍랑경보·대설경보 변...  202212221800
# 1     108     [특보] 제12-234호 : 2022.12.22.16:10 / 대설경보 변경 (*)  202212221610
# 2     108  [특보] 제12-233호 : 2022.12.22.16:00 / 풍랑경보 변경·풍랑주...  202212221600
# 3     108    [특보] 제12-232호 : 2022.12.22.14:00 / 풍랑주의보 발표 (*)  202212221400
# 4     108  [특보] 제12-231호 : 2022.12.22.13:00 / 풍랑경보 변경·대설주...  202212221300
# ..    ...                                                ...           ...
# 107   108  [특보] 제12-129호 : 2022.12.16.18:00 / 풍랑주의보 해제예고연...  202212161800
# 108   108  [특보] 제12-128호 : 2022.12.16.15:00 / 풍랑주의보 해제·풍랑...  202212161500
# 109   108    [특보] 제12-127호 : 2022.12.16.12:00 / 풍랑주의보 해제 (*)  202212161200
# 110   108  [특보] 제12-126호 : 2022.12.16.10:00 / 풍랑주의보 해제·한파...  202212161000
# 111   108    [특보] 제12-125호 : 2022.12.16.03:00 / 강풍주의보 해제 (*)  202212160300
#
#     tmSeq
# 0     235
# 1     234
# 2     233
# 3     232
# 4     231
# ..    ...
# 107   129
# 108   128
# 109   127
# 110   126
# 111   125
#
# [112 rows x 4 columns]

# %%
df.to_csv('기상특보목록조회.csv', encoding = 'utf-8-sig')

# %% [markdown]
# 기상특보통보문조회

# %%
url = 'http://apis.data.go.kr/1360000/WthrWrnInfoService/getWthrWrnMsg'
key = 'buNPq8BZdGw2p%2B3l2B7IMBy3e9PX5fahBKLPiW518y4yMZsQFDJeQW9fpNMb2nt7Xu6j4vz6txHwT5%2BrcFrwhA%3D%3D'

queryParams = f'?{parse.quote_plus("serviceKey")}={key}&' + parse.urlencode({
parse.quote_plus("numOfRows"): 999,
parse.quote_plus("pageNo"): 1,
parse.quote_plus("stnId"): 108,
parse.quote_plus("fromTmFc"): 20221216,
parse.quote_plus("toTmFc"): 20221222,
})

# xml로 받아온 response
response = requests.get(url + queryParams).text
# xmltodict로 dictionary형태로 바꿔줌
jsonString = json.dumps(xmltodict.parse(response), indent=4)
# dictiondary to json
dic = json.loads(jsonString)
dic
body = dic['response']['body']['items']['item']

df = pd.json_normalize(body)
df
# Out:
#     stnId                                              other  \
# 0     108  (1) 대설경보 변경 : 전라남도(담양), 전라북도(완주, 익산, 전주), 광주\n...
# 1     108  (1) 대설경보 변경 : 전라북도(남원)\no 현재 적설(12월 22일 03시~현재...
# 2     108  (6) 대설경보 변경 : 제주도(제주도북부중산간)\no 현재 적설(12월 22일 0...
# 3     108                                               o 없음
# 4     108  (2) 대설주의보 발표 : 제주도(추자도)\no 현재 적설(12월 22일 03시~현...
# ..    ...                                                ...
# 106   108  o 당초, 오늘(16일) 오후로 예고되었던, 동해중부바깥먼바다의 풍랑특보 해제예고를...
# 107   108                                               o 없음
# 108   108                                               o 없음
# 109   108                                               o 없음
# 110   108                                               o 없음
#
#                                  t1  \
# 0             풍랑경보·대설경보 변경·대설주의보 발표
# 1                           대설경보 변경
# 2          풍랑경보 변경·풍랑주의보 발표·대설경보 변경
# 3                          풍랑주의보 발표
# 4                  풍랑경보 변경·대설주의보 발표
# ..                              ...
# 106                    풍랑주의보 해제예고연장
# 107               풍랑주의보 해제·풍랑주의보 발표
# 108                        풍랑주의보 해제
# 109  풍랑주의보 해제·한파경보·건조경보 변경·건조주의보 발표
# 110                        강풍주의보 해제
#
#                                                     t2  \
# 0    (1) 대설경보 변경 : 전라남도(담양), 전라북도(완주, 익산, 전주), 광주\r...
# 1                               (1) 대설경보 변경 : 전라북도(남원)
# 2    (1) 풍랑주의보 발표 : 남해서부앞바다\r\n(2) 풍랑주의보 발표 : 동해남부앞...
# 3             (1) 풍랑주의보 발표 : 동해남부앞바다(경북남부앞바다, 경북북부앞바다)
# 4    (1) 풍랑경보 변경 : 제주도남쪽바깥먼바다\r\n(2) 대설주의보 발표 : 제주도...
# ..                                                 ...
# 106                           (1) 풍랑주의보 연장 : 동해중부바깥먼바다
# 107  (1) 풍랑주의보 발표 : 제주도남쪽바깥먼바다\r\n(2) 풍랑주의보 해제 : 동해...
# 108                           (1) 풍랑주의보 해제 : 동해중부안쪽먼바다
# 109  (1) 한파경보 변경 : 강원도(양구평지, 인제평지)\r\n(2) 건조주의보 발표 ...
# 110                              (1) 강풍주의보 해제 : 울릉도.독도
#
#                                                     t3  \
# 0    (1) 대설경보 변경 : 2022년 12월 22일 18시 00분\r\n(2) 풍랑경...
# 1                  (1) 대설경보 변경 : 2022년 12월 22일 16시 10분
# 2    (1) 풍랑주의보 발표 : 2022년 12월 22일 18시 00분\r\n(2) 풍랑...
# 3                 (1) 풍랑주의보 발표 : 2022년 12월 22일 16시 00분
# 4    (1) 풍랑경보 변경 : 2022년 12월 22일 15시 00분\r\n(2) 대설주...
# ..                                                 ...
# 106               (1) 풍랑주의보 연장 : 2022년 12월 16일 18시 00분
# 107  (1) 풍랑주의보 발표 : 2022년 12월 16일 17시 00분\r\n(2) 풍랑...
# 108               (1) 풍랑주의보 해제 : 2022년 12월 16일 15시 00분
# 109  (1) 한파경보 변경 : 2022년 12월 16일 10시 00분\r\n(2) 건조주...
# 110               (1) 강풍주의보 해제 : 2022년 12월 16일 04시 00분
#
#                                                     t4            t5  \
# 0    (2) 풍랑경보 변경\r\n  o 해제 예고: 25일 늦은 오후(15시~18시)\r...  202212222000
# 1                                                 None  202212221800
# 2    (1) 풍랑주의보 발표\r\n  o 해제 예고: 24일 밤(21시~24시)\r\n(...  202212221800
# 3            (1) 풍랑주의보 발표\r\n  o 해제 예고: 25일 밤(21시~24시)  202212221800
# 4    (1) 풍랑경보 변경\r\n  o 해제 예고: 26일 새벽(03시~06시)\r\n(...  202212221800
# ..                                                 ...           ...
# 106      (1) 풍랑주의보 연장\r\n  o 해제 예고: 20일 늦은 오후(15시~18시)  202212161800
# 107      (1) 풍랑주의보 발표\r\n  o 해제 예고: 19일 늦은 오후(15시~18시)  202212161700
# 108                                               None  202212161500
# 109                                               None  202212161200
# 110                                               None  202212160400
#
#                                                     t6  \
# 0    o 강풍경보 : 전라남도(흑산도.홍도)\r\no 강풍주의보 : 경기도(안산, 시흥,...
# 1    o 강풍경보 : 전라남도(흑산도.홍도)\r\no 강풍주의보 : 경기도(안산, 시흥,...
# 2    o 강풍경보 : 전라남도(흑산도.홍도)\r\no 강풍주의보 : 경기도(안산, 시흥,...
# 3    o 강풍경보 : 전라남도(흑산도.홍도)\r\no 강풍주의보 : 경기도(안산, 시흥,...
# 4    o 강풍경보 : 전라남도(흑산도.홍도)\r\no 강풍주의보 : 경기도(안산, 시흥,...
# ..                                                 ...
# 106  o 풍랑주의보 : 동해중부바깥먼바다, 제주도남쪽바깥먼바다\r\no 한파경보 : 강원...
# 107  o 풍랑주의보 : 동해중부바깥먼바다, 제주도남쪽바깥먼바다\r\no 한파경보 : 강원...
# 108  o 풍랑주의보 : 동해남부북쪽바깥먼바다, 동해중부바깥먼바다\r\no 한파경보 : 강...
# 109  o 풍랑주의보 : 동해남부북쪽바깥먼바다, 동해중부안쪽먼바다, 동해중부바깥먼바다\r\...
# 110  o 풍랑주의보 : 동해남부북쪽안쪽먼바다, 동해남부북쪽바깥먼바다, 동해중부안쪽먼바다,...
#
#                                                     t7          tmFc tmSeq  \
# 0    (1) 대설 예비특보\r\no 12월 22일 밤(18시~24시) : 울릉도.독도\r...  202212221800   235
# 1    (1) 대설 예비특보\r\no 12월 22일 밤(18시~24시) : 제주도(제주도서...  202212221610   234
# 2    (1) 대설 예비특보\r\no 12월 22일 밤(18시~24시) : 제주도(제주도서...  202212221600   233
# 3    (1) 풍랑 예비특보\r\no 12월 22일 밤(18시~24시) : 동해남부앞바다(...  202212221400   232
# 4    (1) 풍랑 예비특보\r\no 12월 22일 오후(12시~18시) : 동해남부앞바다...  202212221300   231
# ..                                                 ...           ...   ...
# 106  (1) 강풍 예비특보\r\no 12월 17일 새벽(00시~06시) : 서해5도\r\...  202212161800   129
# 107  (1) 강풍 예비특보\r\no 12월 17일 새벽(00시~06시) : 서해5도\r\...  202212161500   128
# 108  (1) 풍랑 예비특보\r\no 12월 16일 오후(12시~18시) : 제주도남쪽바깥...  202212161200   127
# 109  (1) 풍랑 예비특보\r\no 12월 16일 오후(12시~18시) : 제주도남쪽바깥...  202212161000   126
# 110  (1) 풍랑 예비특보\r\no 12월 16일 오후(12시~18시) : 제주도남쪽바깥먼바다  202212160300   125
#
#     warFc
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
# ..    ...
# 106     1
# 107     1
# 108     1
# 109     1
# 110     1
#
# [111 rows x 12 columns]

# %%
df.to_csv('기상특보통보문조회.csv', encoding = 'utf-8-sig')

# %% [markdown]
# 기상정보목록조회

# %%
url = 'http://apis.data.go.kr/1360000/WthrWrnInfoService/getWthrInfoList'
key = 'buNPq8BZdGw2p%2B3l2B7IMBy3e9PX5fahBKLPiW518y4yMZsQFDJeQW9fpNMb2nt7Xu6j4vz6txHwT5%2BrcFrwhA%3D%3D'

queryParams = f'?{parse.quote_plus("serviceKey")}={key}&' + parse.urlencode({
parse.quote_plus("numOfRows"): 999,
parse.quote_plus("pageNo"): 1,
parse.quote_plus("stnId"): 108,
parse.quote_plus("fromTmFc"): 20221216,
parse.quote_plus("toTmFc"): 20221222,
})

# xml로 받아온 response
response = requests.get(url + queryParams).text
# xmltodict로 dictionary형태로 바꿔줌
jsonString = json.dumps(xmltodict.parse(response), indent=4)
# dictiondary to json
dic = json.loads(jsonString)
dic
body = dic['response']['body']['items']['item']

df = pd.json_normalize(body)
df
# Out:
#    stnId                            title          tmFc tmSeq
# 0    108  [정보] 제12-41호 : 2022.12.16.06:20  202212160620    41
# 1    108  [정보] 제12-42호 : 2022.12.17.04:30  202212170430    42
# 2    108  [정보] 제12-43호 : 2022.12.17.05:30  202212170530    43
# 3    108  [정보] 제12-44호 : 2022.12.17.09:20  202212170920    44
# 4    108  [정보] 제12-45호 : 2022.12.17.12:10  202212171210    45
# 5    108  [정보] 제12-46호 : 2022.12.18.06:10  202212180610    46
# 6    108  [정보] 제12-47호 : 2022.12.18.09:30  202212180930    47
# 7    108  [정보] 제12-48호 : 2022.12.18.17:50  202212181750    48
# 8    108  [정보] 제12-49호 : 2022.12.21.17:20  202212211720    49
# 9    108  [정보] 제12-50호 : 2022.12.21.18:10  202212211810    50
# 10   108  [정보] 제12-51호 : 2022.12.21.19:20  202212211920    51
# 11   108  [정보] 제12-52호 : 2022.12.22.01:10  202212220110    52
# 12   108  [정보] 제12-53호 : 2022.12.22.04:30  202212220430    53
# 13   108  [정보] 제12-54호 : 2022.12.22.17:20  202212221720    54

# %%
df.to_csv('기상정보목록조회.csv', encoding = 'utf-8-sig')

# %% [markdown]
# 기상정보문조회

# %%
url = 'http://apis.data.go.kr/1360000/WthrWrnInfoService/getWthrInfo'
key = 'buNPq8BZdGw2p%2B3l2B7IMBy3e9PX5fahBKLPiW518y4yMZsQFDJeQW9fpNMb2nt7Xu6j4vz6txHwT5%2BrcFrwhA%3D%3D'

queryParams = f'?{parse.quote_plus("serviceKey")}={key}&' + parse.urlencode({
parse.quote_plus("numOfRows"): 999,
parse.quote_plus("pageNo"): 1,
parse.quote_plus("stnId"): 108,
parse.quote_plus("fromTmFc"): 20221216,
parse.quote_plus("toTmFc"): 20221222,
})

# xml로 받아온 response
response = requests.get(url + queryParams).text
# xmltodict로 dictionary형태로 바꿔줌
jsonString = json.dumps(xmltodict.parse(response), indent=4)
# dictiondary to json
dic = json.loads(jsonString)
dic
body = dic['response']['body']['items']['item']

df = pd.json_normalize(body)
df
# Out:
#    stnId                                                 t1          tmFc  \
# 0    108  < 기상 현황과 전망 >\n○ 현재(17시), 충남서해안과 전라권, 제주도에는 시간...  202212221720
# 1    108  < 기상 현황과 전망 >\n○ (현황) 현재(04시 20분), 충청권과 전라권, 제...  202212220430
# 2    108  < 강수 현황과 전망 >\n○ (현황) 현재(01시), 충남권과 전라권에 시간당 1...  202212220110
# 3    108  < 현황과 전망 >\n○ 현재(19시), 수도권과 충청권, 강원영서, 경상서부내륙에...  202212211920
# 4    108  < 강수 현황과 전망 >\n\n○ 현재(18시), 경기서해안과 경기남부내륙, 충청권...  202212211810
# 5    108  < 강수 현황과 전망 >\n\n○ 현재(17시), 제주도산지에는 시간당 1cm 내외...  202212211720
# 6    108  < 강수 현황과 전망 >\n○ (현황) 현재(17시 40분), 전남해안과 충남서해안...  202212181750
# 7    108  < 강수 현황과 전망 >\n○ (현황) 현재(09시 10분), 전남권에는 시간당 2...  202212180930
# 8    108  < 강수 현황과 전망 >\n○ (현황) 현재(06시), 전북서해안과 전남권(동부내륙...  202212180610
# 9    108  <눈 현황과 전망>\n○ 현재(12시), 충남권과 전라권, 제주도에 대설특보가 발효...  202212171210
# 10   108  <눈 현황과 전망>\n○ 현재(09시), 충청권과 전라권, 일부 인천.경기남부, 제...  202212170920
# 11   108  < 눈 현황과 전망 >\n○ (현황) 현재(05시 20분), 전국이 대체로 흐린 가...  202212170530
# 12   108  < 눈 현황과 전망 >\n○ (현황) 현재(04시 20분) 전국이 대체로 흐린 가운...  202212170430
# 13   108  < 기온 현황과 전망 >\n○ 현재(06시), 기온은 한파특보가 발효 중인 경기내륙...  202212160620
#
#    tmSeq
# 0     54
# 1     53
# 2     52
# 3     51
# 4     50
# 5     49
# 6     48
# 7     47
# 8     46
# 9     45
# 10    44
# 11    43
# 12    42
# 13    41

# %%
df.to_csv('기상정보문조회.csv', encoding = 'utf-8-sig')

# %% [markdown]
# 기상속보목록조회

# %%
url = 'http://apis.data.go.kr/1360000/WthrWrnInfoService/getWthrBrkNewsList'
key = 'buNPq8BZdGw2p%2B3l2B7IMBy3e9PX5fahBKLPiW518y4yMZsQFDJeQW9fpNMb2nt7Xu6j4vz6txHwT5%2BrcFrwhA%3D%3D'

queryParams = f'?{parse.quote_plus("serviceKey")}={key}&' + parse.urlencode({
parse.quote_plus("numOfRows"): 999,
parse.quote_plus("pageNo"): 1,
parse.quote_plus("stnId"): 108,
parse.quote_plus("fromTmFc"): 20221216,
parse.quote_plus("toTmFc"): 20221222,
})

# xml로 받아온 response
response = requests.get(url + queryParams).text
# xmltodict로 dictionary형태로 바꿔줌
jsonString = json.dumps(xmltodict.parse(response), indent=4)
# dictiondary to json
dic = json.loads(jsonString)
dic
body = dic['response']['body']['items']['item']

df = pd.json_normalize(body)
df
# Out:
#    stnId                             title          tmFc tmSeq
# 0    108   [속보] 제12-40호 : 2022.12.17.05:10  202212170510    40
# 1    108   [속보] 제12-41호 : 2022.12.17.06:10  202212170610    41
# 2    108   [속보] 제12-42호 : 2022.12.17.07:10  202212170710    42
# 3    108   [속보] 제12-43호 : 2022.12.17.08:10  202212170810    43
# 4    108   [속보] 제12-44호 : 2022.12.17.09:10  202212170910    44
# ..   ...                               ...           ...   ...
# 78   108  [속보] 제12-118호 : 2022.12.22.13:10  202212221310   118
# 79   108  [속보] 제12-119호 : 2022.12.22.14:10  202212221410   119
# 80   108  [속보] 제12-120호 : 2022.12.22.15:10  202212221510   120
# 81   108  [속보] 제12-121호 : 2022.12.22.16:10  202212221610   121
# 82   108  [속보] 제12-122호 : 2022.12.22.17:10  202212221710   122
#
# [83 rows x 4 columns]

# %%
df.to_csv('기상속보목록조회.csv', encoding = 'utf-8-sig')

# %% [markdown]
# 기상속보조회

# %%
url = 'http://apis.data.go.kr/1360000/WthrWrnInfoService/getWthrBrkNews'
key = 'buNPq8BZdGw2p%2B3l2B7IMBy3e9PX5fahBKLPiW518y4yMZsQFDJeQW9fpNMb2nt7Xu6j4vz6txHwT5%2BrcFrwhA%3D%3D'

queryParams = f'?{parse.quote_plus("serviceKey")}={key}&' + parse.urlencode({
parse.quote_plus("numOfRows"): 999,
parse.quote_plus("pageNo"): 1,
parse.quote_plus("stnId"): 108,
parse.quote_plus("fromTmFc"): 20221216,
parse.quote_plus("toTmFc"): 20221222,
})

# xml로 받아온 response
response = requests.get(url + queryParams).text
# xmltodict로 dictionary형태로 바꿔줌
jsonString = json.dumps(xmltodict.parse(response), indent=4)
# dictiondary to json
dic = json.loads(jsonString)
dic
body = dic['response']['body']['items']['item']

df = pd.json_normalize(body)
df
# for i in range(2, 1727):
#     queryParams = f'?{parse.quote_plus("serviceKey")}={key}&' + parse.urlencode({
#     parse.quote_plus("dataCd"): 'ASOS',
#     parse.quote_plus("dateCd"): 'HR',
#     parse.quote_plus("startDt"): '20210101',
#     parse.quote_plus("startHh"): '01',
#     parse.quote_plus("endDt"): '20221221',
#     parse.quote_plus("endHh"): '01',
#     parse.quote_plus("stnIds"): '112',
#     parse.quote_plus("pageNo"): i,
#     })

#     # xml로 받아온 response
#     response = requests.get(url + queryParams).text
#     # xmltodict로 dictionary형태로 바꿔줌
#     jsonString = json.dumps(xmltodict.parse(response), indent=4)
#     # dictiondary to json
#     dic = json.loads(jsonString)
#     #dic
#     body = dic['response']['body']['items']['item']

#     dataframe = pd.json_normalize(body)
#     df = pd.concat([df, dataframe])
# df
# Out:
#    stnId          tmFc tmSeq  \
# 0    108  202212221710   122
# 1    108  202212221610   121
# 2    108  202212221510   120
# 3    108  202212221410   119
# 4    108  202212221310   118
# ..   ...           ...   ...
# 81   108  202212170910    44
# 82   108  202212170810    43
# 83   108  202212170710    42
# 84   108  202212170610    41
# 85   108  202212170510    40
#
#                                                   ann cnt
# 0   < 적설 현황과 전망 >\n○ 현재(17시), 충청권과 전라권, 제주도산지를 중심으...   4
# 1   < 적설 현황과 전망 >\n○ 현재(16시), 충청권과 전라권, 제주도산지를 중심으...   4
# 2   < 적설 현황과 전망 >\n○ 현재(15시), 충청권과 전라권을 중심으로 시간당 1...   4
# 3   < 적설 현황과 전망 >\n○ 현재(14시), 충청권과 전라권을 중심으로 시간당 1...   4
# 4   < 적설 현황과 전망 >\n○ 현재(13시), 충청권과 전라권을 중심으로 시간당 1...   4
# ..                                                ...  ..
# 81  < 적설 현황과 전망 >\n○ 현재(09시), 충청권과 전라권, 일부 인천.경기남부...   4
# 82  < 적설 현황과 전망 >\n○ 현재(08시), 충남권과 전라권서부, 일부 인천에 대...   4
# 83  < 적설 현황과 전망 >\n○ 현재(07시), 충남서해안과 전라서해안을 중심으로 시...   4
# 84  < 적설 현황과 전망 >\n○ 현재(06시), 서해5도와 충남서해안, 전라서해안을 ...   4
# 85  ○ 현재(05시), 충남서해안과 전라서해안, 제주도산지에 대설특보가 발효된 가운데,...   4
#
# [86 rows x 5 columns]

# %%
df.to_csv('기상속보조회.csv', encoding = 'utf-8-sig')

# %% [markdown]
# 기상예비특보목록조회

# %%
url = 'http://apis.data.go.kr/1360000/WthrWrnInfoService/getWthrPwnList'
key = 'buNPq8BZdGw2p%2B3l2B7IMBy3e9PX5fahBKLPiW518y4yMZsQFDJeQW9fpNMb2nt7Xu6j4vz6txHwT5%2BrcFrwhA%3D%3D'

queryParams = f'?{parse.quote_plus("serviceKey")}={key}&' + parse.urlencode({
parse.quote_plus("numOfRows"): 999,
parse.quote_plus("pageNo"): 1,
parse.quote_plus("stnId"): 108,
parse.quote_plus("fromTmFc"): 20221216,
parse.quote_plus("toTmFc"): 20221222,
})

# xml로 받아온 response
response = requests.get(url + queryParams).text
# xmltodict로 dictionary형태로 바꿔줌
jsonString = json.dumps(xmltodict.parse(response), indent=4)
# dictiondary to json
dic = json.loads(jsonString)
dic
body = dic['response']['body']['items']['item']

df = pd.json_normalize(body)
df
# Out:
#    stnId                            title          tmFc tmSeq
# 0    108  [예비] 제12-30호 : 2022.12.22.11:10  202212221110    30
# 1    108  [예비] 제12-29호 : 2022.12.22.04:00  202212220400    29
# 2    108  [예비] 제12-28호 : 2022.12.21.18:10  202212211810    28
# 3    108  [예비] 제12-27호 : 2022.12.21.16:10  202212211610    27
# 4    108  [예비] 제12-26호 : 2022.12.21.10:40  202212211040    26
# 5    108  [예비] 제12-25호 : 2022.12.21.06:00  202212210600    25
# 6    108  [예비] 제12-24호 : 2022.12.21.04:00  202212210400    24
# 7    108  [예비] 제12-23호 : 2022.12.20.11:00  202212201100    23
# 8    108  [예비] 제12-22호 : 2022.12.19.00:00  202212190000    22
# 9    108  [예비] 제12-21호 : 2022.12.18.17:00  202212181700    21
# 10   108  [예비] 제12-20호 : 2022.12.18.11:10  202212181110    20
# 11   108  [예비] 제12-19호 : 2022.12.18.09:10  202212180910    19
# 12   108  [예비] 제12-18호 : 2022.12.17.04:00  202212170400    18
# 13   108  [예비] 제12-17호 : 2022.12.16.16:00  202212161600    17
# 14   108  [예비] 제12-16호 : 2022.12.16.04:00  202212160400    16

# %%
df.to_csv('기상예비특보목록조회.csv', encoding = 'utf-8-sig')

# %% [markdown]
# 기상예비특보조회

# %%
url = 'http://apis.data.go.kr/1360000/WthrWrnInfoService/getWthrPwn'
key = 'buNPq8BZdGw2p%2B3l2B7IMBy3e9PX5fahBKLPiW518y4yMZsQFDJeQW9fpNMb2nt7Xu6j4vz6txHwT5%2BrcFrwhA%3D%3D'

queryParams = f'?{parse.quote_plus("serviceKey")}={key}&' + parse.urlencode({
parse.quote_plus("numOfRows"): 999,
parse.quote_plus("pageNo"): 1,
parse.quote_plus("stnId"): 108,
parse.quote_plus("fromTmFc"): 20221216,
parse.quote_plus("toTmFc"): 20221222,
})

# xml로 받아온 response
response = requests.get(url + queryParams).text
# xmltodict로 dictionary형태로 바꿔줌
jsonString = json.dumps(xmltodict.parse(response), indent=4)
# dictiondary to json
dic = json.loads(jsonString)
dic
body = dic['response']['body']['items']['item']

df = pd.json_normalize(body)
df
# Out:
#    stnId          tmFc tmSeq  \
# 0    108  202212221110    30
# 1    108  202212220400    29
# 2    108  202212211810    28
# 3    108  202212211610    27
# 4    108  202212211040    26
# 5    108  202212210600    25
# 6    108  202212210400    24
# 7    108  202212201100    23
# 8    108  202212190000    22
# 9    108  202212181700    21
# 10   108  202212181110    20
# 11   108  202212180910    19
# 12   108  202212170400    18
# 13   108  202212161600    17
# 14   108  202212160400    16
#
#                                                   pwn  \
# 0   (1) 강풍 예비특보\r\no 12월 23일 새벽(00시~06시) : 경상남도(산청...
# 1   (1) 강풍 예비특보\r\no 12월 22일 아침(06시~09시) : 강원도(강릉평...
# 2   (1) 강풍 예비특보\r\no 12월 21일 밤(18시~24시) : 강원도(태백, ...
# 3   (1) 강풍 예비특보\r\no 12월 21일 오후(12시~18시) : 전라남도(흑산...
# 4   (1) 강풍 예비특보\r\no 12월 21일 오전(09시~12시) : 서해5도\r\...
# 5   (1) 강풍 예비특보\r\no 12월 21일 오전(09시~12시) : 서해5도\r\...
# 6   (1) 강풍 예비특보\r\no 12월 21일 오전(09시~12시) : 서해5도\r\...
# 7   (1) 강풍 예비특보\r\no 12월 21일 오전(09시~12시) : 서해5도\r\...
# 8                                                o 없음
# 9   (1) 대설 예비특보\r\no 12월 18일 밤(18시~24시) : 충청남도(부여,...
# 10  (1) 대설 예비특보\r\no 12월 18일 늦은 오후(15시~18시) : 충청남도...
# 11  (1) 대설 예비특보\r\no 12월 18일 늦은 오후(15시~18시) : 충청남도...
# 12  (1) 강풍 예비특보\r\no 12월 17일 새벽(00시~06시) : 서해5도\r\...
# 13  (1) 강풍 예비특보\r\no 12월 17일 새벽(00시~06시) : 서해5도\r\...
# 14  (1) 강풍 예비특보\r\no 12월 17일 새벽(00시~06시) : 서해5도\r\...
#
#                                                   rem
# 0                         o 울릉도.독도에 대설예비특보를 추가 발표합니다.
# 1   o 예비특보 추가 발표 지역/발효 시각\n - 강풍 예비특보: 경상남도(산청,통영,...
# 2   o 충청북도(청주,보은,옥천,영동), 경상북도(김천), 전라남도(고흥,보성,순천),...
# 3                        o 동해남부앞바다에 풍랑예비특보를 추가 발표합니다.
# 4   o 12월 22일 새벽(00시~06시) : 충청남도(금산 제외), 전라남도(나주, ...
# 5   o 당초, 오늘(21일) 새벽으로 예고되었던 경기도(오산,평택,안성,화성)의 대설 ...
# 6   o 제주도북부중산간 : 제주시 내 해발고도 200∼600m 사이 지역\r\no 제주...
# 7   (2) 풍랑경보가 다음과 같이 예상되오니 앞으로 발표되는 기상특보를 참고하기 바랍니...
# 8   o 당초, 오늘(18일) 밤으로 예고되었던 충청남도(부여, 청양, 예산)의 대설 예...
# 9   o 당초 오늘(18일) 늦은 오후로 예고되었던 충청남도(부여, 청양, 예산, 태안,...
# 10           o 전라북도(고창, 부안, 군산, 김제)의 대설예비특보를 추가발표합니다.
# 11                                               o 없음
# 12  o 제주도(제주도서부, 제주도북부, 제주도동부, 제주도남부)의 대설예비특보를 추가 ...
# 13  o 제주도북부중산간 : 제주시 내 해발고도 200∼600m 사이 지역\r\no 제주...
# 14                       o 위 구역의 강풍 및 풍랑 예비특보를 발표합니다.

# %%
df.to_csv('기상예비특보조회.csv', encoding = 'utf-8-sig')

# %% [markdown]
# 특보코드조회

# %%
url = 'http://apis.data.go.kr/1360000/WthrWrnInfoService/getPwnCd'
key = 'buNPq8BZdGw2p%2B3l2B7IMBy3e9PX5fahBKLPiW518y4yMZsQFDJeQW9fpNMb2nt7Xu6j4vz6txHwT5%2BrcFrwhA%3D%3D'

queryParams = f'?{parse.quote_plus("serviceKey")}={key}&' + parse.urlencode({
parse.quote_plus("numOfRows"): 999,
parse.quote_plus("pageNo"): 1,
parse.quote_plus("stnId"): 108,
parse.quote_plus("fromTmFc"): 20221216,
parse.quote_plus("toTmFc"): 20221222,
})

# xml로 받아온 response
response = requests.get(url + queryParams).text
# xmltodict로 dictionary형태로 바꿔줌
jsonString = json.dumps(xmltodict.parse(response), indent=4)
# dictiondary to json
dic = json.loads(jsonString)
dic
body = dic['response']['body']['items']['item']

df = pd.json_normalize(body)
#df

queryParams = f'?{parse.quote_plus("serviceKey")}={key}&' + parse.urlencode({
parse.quote_plus("numOfRows"): 999,
parse.quote_plus("pageNo"): 2,
parse.quote_plus("stnId"): 108,
parse.quote_plus("fromTmFc"): 20221216,
parse.quote_plus("toTmFc"): 20221222,
})

# xml로 받아온 response
response = requests.get(url + queryParams).text
# xmltodict로 dictionary형태로 바꿔줌
jsonString = json.dumps(xmltodict.parse(response), indent=4)
# dictiondary to json
dic = json.loads(jsonString)
dic
body = dic['response']['body']['items']['item']

df1 = pd.json_normalize(body)
#df1

df = pd.concat([df, df1])
df
# Out:
#        allEndTime  areaCode     areaName cancel command       endTime stnId  \
# 0               0  S1323400     제주도서부앞바다      0       7             0   108
# 1               0  S1323100     제주도북부앞바다      0       7             0   108
# 2               0  S1322100    남해서부서쪽먼바다      0       7             0   108
# 3               0  S1132220  동해남부북쪽바깥먼바다      0       7             0   108
# 4               0  L1090900        제주도남부      0       1             0   108
# ..            ...       ...          ...    ...     ...           ...   ...
# 226             0  L1072400          포항시      0       1             0   108
# 227             0  L1072500          경주시      0       1             0   108
# 228             0  L1075020       경북북동산지      0       1             0   108
# 229  202212161200  S1132210  동해남부북쪽안쪽먼바다      0       2  202212161200   108
# 230  202212160400  L1072100       울릉도.독도      0       2  202212160400   108
#
#              tmFc tmSeq warnVar warnStress     startTime
# 0    202212221800   235       6          1  202212222000
# 1    202212221800   235       6          1  202212222000
# 2    202212221800   235       6          1  202212222000
# 3    202212221800   235       6          1  202212222000
# 4    202212221800   235       8          0  202212222000
# ..            ...   ...     ...        ...           ...
# 226  202212161000   126       4          0  202212161000
# 227  202212161000   126       4          0  202212161000
# 228  202212161000   126       4          0  202212161000
# 229  202212161000   126       6          0             0
# 230  202212160300   125       1          0             0
#
# [1230 rows x 12 columns]

# %%
df.to_csv('특보코드조회.csv', encoding = 'utf-8-sig')

# %% [markdown]
# 특보현황조회

# %%
url = 'http://apis.data.go.kr/1360000/WthrWrnInfoService/getPwnStatus'
key = 'buNPq8BZdGw2p%2B3l2B7IMBy3e9PX5fahBKLPiW518y4yMZsQFDJeQW9fpNMb2nt7Xu6j4vz6txHwT5%2BrcFrwhA%3D%3D'

queryParams = f'?{parse.quote_plus("serviceKey")}={key}&' + parse.urlencode({
parse.quote_plus("numOfRows"): 999,
parse.quote_plus("pageNo"): 1,
parse.quote_plus("stnId"): 108,
parse.quote_plus("fromTmFc"): 20221216,
parse.quote_plus("toTmFc"): 20221222,
})

# xml로 받아온 response
response = requests.get(url + queryParams).text
# xmltodict로 dictionary형태로 바꿔줌
jsonString = json.dumps(xmltodict.parse(response), indent=4)
# dictiondary to json
dic = json.loads(jsonString)
dic
body = dic['response']['body']['items']['item']

df = pd.json_normalize(body)
df
# Out:
#                                                other  \
# 0  (1) 대설경보 변경 : 전라남도(담양), 전라북도(완주, 익산, 전주), 광주\n...
#
#                                                   t6  \
# 0  o 강풍경보 : 전라남도(흑산도.홍도)\r\no 강풍주의보 : 경기도(안산, 시흥,...
#
#                                                   t7          tmEf  \
# 0  (1) 대설 예비특보\r\no 12월 22일 밤(18시~24시) : 울릉도.독도\r...  202212222000
#
#            tmFc tmSeq
# 0  202212221800   235

# %%
df.to_csv('특보현황조회.csv', encoding = 'utf-8-sig')
