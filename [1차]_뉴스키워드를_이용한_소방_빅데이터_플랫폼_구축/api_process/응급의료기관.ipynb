# %%
import pandas as pd
import json
import requests
from urllib import parse
import xmltodict

# %%
url = 'http://apis.data.go.kr/B552657/ErmctInfoInqireService/getEgytListInfoInqire'
key = 'qIlLlTZnU9ipgBO8frY4eIlcT5n%2BeoMENWFJFtdpD0oWo7kG4nEtn5eyxLs50fBoULGJMSW2oDPXQxgyyMurtQ%3D%3D'

queryParams = f'?{parse.quote_plus("serviceKey")}={key}&' + parse.urlencode({
#parse.quote_plus("STAGE1"): '서울특별시',
#parse.quote_plus("STAGE2"): '마포구',
parse.quote_plus("numOfRows"): 500,
parse.quote_plus("pageNo"): 1,
})

# xml로 받아온 response
response = requests.get(url + queryParams).text
# xmltodict로 dictionary형태로 바꿔줌
jsonString = json.dumps(xmltodict.parse(response), indent=4)
# dictiondary to json
dic = json.loads(jsonString)

body = dic['response']['body']['items']['item']
dataframe = pd.json_normalize(body)

# %%
dataframe
# Out:
#                                            dutyAddr dutyEmcls dutyEmclsName  \
# 0                           부산광역시 기장군 기장읍 대청로72번길 6      G007      지역응급의료기관
# 1    인천광역시 서구 칠천왕로33번길 17 (석남동, 신석로 70(석남1동, 성민병원))      G007      지역응급의료기관
# 2         경기도 용인시 처인구 백옥대로1082번길 18, 다보스종합병원 (김량장동)      G006      지역응급의료센터
# 3                          경기도 용인시 처인구 고림로 81 (고림동)      G007      지역응급의료기관
# 4                대구광역시 수성구 달구벌대로 3190 (신매동, 천주성삼병원)      G007      지역응급의료기관
# ..                                              ...       ...           ...
# 404                  강원도 화천군 화천읍 강변로 111 (화천군보건의료원)      G007      지역응급의료기관
# 405                             강원도 횡성군 횡성읍 횡성로 275      G007      지역응급의료기관
# 406                  경기도 안양시 만안구 삼덕로 9 (안양동, 안양샘병원)      G006      지역응급의료센터
# 407               경기도 군포시 군포로 591 (당동, (G샘병원)군포샘병원)      G006      지역응급의료센터
# 408                        서울특별시 금천구 시흥대로 244 (시흥동)      G007      지역응급의료기관
#
#                   dutyName       dutyTel1       dutyTel3      hpid     phpid  \
# 0            (의)서일의료재단기장병원   051-723-0171   051-723-2119  A1200028  A1200028
# 1          (의)성세의료재단 뉴성민병원   032-726-1000   032-726-1190  A1400008  A1400008
# 2          (의)영문의료재단 다보스병원  031-8021-2114  031-8021-2130  A2100019  A2100019
# 3          (의)효심의료재단용인서울병원   031-337-0114   031-336-0119  A2100122  A2100122
# 4    (재)미리내천주성삼성직수도회천주성삼병원   053-790-1000   053-790-0555  A1300081  A1300081
# ..                     ...            ...            ...       ...       ...
# 404               화천군보건의료원   033-442-7115   033-440-2880  E2200025  E2200025
# 405                 횡성대성병원   033-343-0901   033-345-1191  A2200016  A2200016
# 406            효산의료재단안양샘병원   031-467-9717   031-467-9119  A2100015  A2100015
# 407             효산의료재단지샘병원   031-389-3000   031-389-3119  A2100054  A2100054
# 408                   희명병원    02-804-0002    02-809-0122  A1100049  A1100049
#
#     rnum            wgs84Lat            wgs84Lon
# 0      1   35.23602946449906  129.21649161387128
# 1      2    37.5089936801167    126.669478649026
# 2      3  37.234641294534285  127.21049868474802
# 3      4        37.240316373      127.2144914405
# 4      5   35.84022544517349  128.70573339664242
# ..   ...                 ...                 ...
# 404  405    38.1073824571151    127.708883438378
# 405  406   37.47845901170136  127.97994775890871
# 406  407   37.39340413136221  126.92447734066778
# 407  408   37.35864464913468  126.94735972779895
# 408  409   37.45567063464179  126.90056251863875
#
# [409 rows x 11 columns]

# %%
dataframe.to_csv('응급의료기관.csv', encoding = 'utf-8-sig')
