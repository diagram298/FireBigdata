# %%
import folium
import pandas as pd

# %%
df1 = pd.read_csv('전국 소방서 현황.csv', encoding = 'cp949')
df2 = pd.read_csv('전국 119안전센터 현황.csv', encoding = 'cp949')

# %%
df1
# Out:
#       순번 본부명     소방서                              주소          전화번호
# 0      1  서울   종로소방서                서울특별시 종로구 율곡로 78  02-6981-5600
# 1      2  서울   중부소방서                서울특별시 중구 퇴계로 394  02-2233-1219
# 2      3  서울   광진소방서              서울특별시 광진구 광나루로 480  02-6981-6600
# 3      4  서울   용산소방서              서울특별시 용산구 한강대로 167  02-6943-1400
# 4      5  서울  동대문소방서               서울특별시 동대문구 장한로 34  02-6942-1200
# ..   ...  ..     ...                             ...           ...
# 225  226  제주   서부소방서       제주특별자치도 제주시 한림읍 한림중앙로 150  064-795-0101
# 226  227  제주   동부소방서  제주특별자치도 서귀포시 성산읍 일주동로 4120번길 7  064-780-9133
# 227  228  창원   의창소방서       경상남도 창원시 의창구 의창대로272번길 10  055-225-9200
# 228  229  창원   성산소방서            경상남도 창원시 의창구 상남로 165  055-211-9200
# 229  230  창원   마산소방서         경상남도 창원시 마산합포구 제2부두로 55  055-249-9200
#
# [230 rows x 5 columns]

# %%
df1.columns.tolist()
# Out:
# ['순번', '본부명', '소방서', '주소', '전화번호']

# %%
df1['본부명'].value_counts()
# Out:
# 서울     25
# 경기     24
# 전남     20
# 경북     19
# 강원     18
# 경남     18
# 충남     16
# 전북     13
# 충북     12
# 경기북    11
# 부산     11
# 인천     10
# 대구      8
# 울산      6
# 대전      5
# 광주      5
# 제주      4
# 창원      3
# 세종      2
# Name: 본부명, dtype: int64

# %%
cond1 = (df1['본부명'] == '서울')
cond2 = (df1['본부명'] == '경기')

df1_capital = df1.loc[cond1 | cond2]
df1_capital
# Out:
#     순번 본부명      소방서                       주소           전화번호
# 0    1  서울    종로소방서         서울특별시 종로구 율곡로 78   02-6981-5600
# 1    2  서울    중부소방서         서울특별시 중구 퇴계로 394   02-2233-1219
# 2    3  서울    광진소방서       서울특별시 광진구 광나루로 480   02-6981-6600
# 3    4  서울    용산소방서       서울특별시 용산구 한강대로 167   02-6943-1400
# 4    5  서울   동대문소방서        서울특별시 동대문구 장한로 34   02-6942-1200
# 5    6  서울   영등포소방서       서울특별시 영등포구 문래로 197   02-6981-7000
# 6    7  서울    성북소방서      서울특별시 성북구 종암로 27길 3   02-6981-7200
# 7    8  서울    은평소방서        서울특별시 은평구 통일로 962   02-6981-6000
# 8    9  서울    강남소방서       서울특별시 강남구 테헤란로 629   02-6981-7408
# 9   10  서울    서초소방서        서울특별시 서초구 사평대로 67    02-594-0119
# 10  11  서울    강서소방서        서울특별시 강서구 양천로 550   02-6981-5000
# 11  12  서울    강동소방서         서울특별시 강동구 성내로 39   02-6981-7600
# 12  13  서울    마포소방서         서울특별시 마포구 창전로 76   02-6981-7800
# 13  14  서울    도봉소방서        서울특별시 도봉구 도봉로 666   02-6981-8073
# 14  15  서울    구로소방서        서울특별시 구로구 경인로 408   02-6981-6320
# ...

# %%
df2
# Out:
#         순번 시도본부 소방서    119안전센터명                               주소          전화번호
# 0        1   서울  종로  세종로119안전센터                 서울특별시 종로구 율곡로 78  02-6981-5740
# 1        2   서울  종로   신교119안전센터                서울특별시 종로구 자하문로 93   02-737-8119
# 2        3   서울  종로   종로119안전센터                서울특별시 종로구 돈화문로 30   02-747-7119
# 3        4   서울  종로   연건119안전센터                 서울특별시 종로구 대학로 91   02-747-8119
# 4        5   서울  종로   신영119안전센터                서울특별시 종로구 진흥로 477   02-391-0119
# ...    ...  ...  ..         ...                              ...           ...
# 1095  1096   창원  마산   양봉119안전센터         경상남도 창원시 마산회원구 자유무역1길 22  055-249-9412
# 1096  1097   창원  마산   구암119안전센터           경상남도 창원시 마산회원구 팔용로 260  055-249-9420
# 1097  1098   창원  마산   내서119안전센터     경상남도 창원시 마산회원구 내서읍 중리공단로 104  055-249-9430
# 1098  1099   창원  마산   호계119안전센터  경상남도 창원시 마산회원구 내서읍 호계본동3길 59-10  055-249-9444
# 1099  1100   창원  마산   구산119안전센터    경상남도 창원시 마산합포구 구산면 해양관광로 1401  055-249-9450
#
# [1100 rows x 6 columns]

# %%
df2.columns.tolist()
# Out:
# ['순번', '시도본부', '소방서', '119안전센터명', '주소', '전화번호']

# %%
df2['시도본부'].value_counts()
# Out:
# 경기     128
# 서울     119
# 경북     100
# 충남      80
# 경남      77
# 강원      75
# 전남      66
# 경기북     61
# 부산      59
# 인천      55
# 전북      54
# 대구      49
# 충북      43
# 울산      26
# 대전      26
# 창원      25
# 광주      24
# 제주      24
# 세종       9
# Name: 시도본부, dtype: int64

# %%
cond1 = (df2['시도본부'] == '서울')
cond2 = (df2['시도본부'] == '경기')

df2_capital = df2.loc[cond1 | cond2]
df2_capital
# Out:
#       순번 시도본부 소방서    119안전센터명                      주소          전화번호
# 0      1   서울  종로  세종로119안전센터        서울특별시 종로구 율곡로 78  02-6981-5740
# 1      2   서울  종로   신교119안전센터       서울특별시 종로구 자하문로 93   02-737-8119
# 2      3   서울  종로   종로119안전센터       서울특별시 종로구 돈화문로 30   02-747-7119
# 3      4   서울  종로   연건119안전센터        서울특별시 종로구 대학로 91   02-747-8119
# 4      5   서울  종로   신영119안전센터       서울특별시 종로구 진흥로 477   02-391-0119
# ..   ...  ...  ..         ...                     ...           ...
# 490  491   경기  양평   강상119안전센터     경기도 양평군 강상면 송학길 54   031-770-0520
# 491  492   경기  양평   용문119안전센터      경기도 양평군 용문면 연수로 64  031-770-0530
# 492  493   경기  양평   양서119안전센터  경기도 양평군 양서면 양수리 1161-4  031-770-0546
# 493  494   경기  과천   중앙119안전센터          경기도 과천시 통영로 12   02-3314-500
# 494  495   경기  과천   과천119안전센터           경기도 과천시 궁말로30   02-3314-510
#
# [247 rows x 6 columns]

# %%
df1_capital = df1_capital.drop(columns = ['순번'])
df1_capital = df1_capital.rename(columns = {'본부명' : '시도'})
df1_capital
# Out:
#     시도      소방서                       주소           전화번호
# 0   서울    종로소방서         서울특별시 종로구 율곡로 78   02-6981-5600
# 1   서울    중부소방서         서울특별시 중구 퇴계로 394   02-2233-1219
# 2   서울    광진소방서       서울특별시 광진구 광나루로 480   02-6981-6600
# 3   서울    용산소방서       서울특별시 용산구 한강대로 167   02-6943-1400
# 4   서울   동대문소방서        서울특별시 동대문구 장한로 34   02-6942-1200
# 5   서울   영등포소방서       서울특별시 영등포구 문래로 197   02-6981-7000
# 6   서울    성북소방서      서울특별시 성북구 종암로 27길 3   02-6981-7200
# 7   서울    은평소방서        서울특별시 은평구 통일로 962   02-6981-6000
# 8   서울    강남소방서       서울특별시 강남구 테헤란로 629   02-6981-7408
# 9   서울    서초소방서        서울특별시 서초구 사평대로 67    02-594-0119
# 10  서울    강서소방서        서울특별시 강서구 양천로 550   02-6981-5000
# 11  서울    강동소방서         서울특별시 강동구 성내로 39   02-6981-7600
# 12  서울    마포소방서         서울특별시 마포구 창전로 76   02-6981-7800
# 13  서울    도봉소방서        서울특별시 도봉구 도봉로 666   02-6981-8073
# 14  서울    구로소방서        서울특별시 구로구 경인로 408   02-6981-6320
# 15  서울    노원소방서     서울특별시 노원구 한글비석로 1길 8   02-6981-6800
# ...

# %%
len(df1_capital)
# Out:
# 49

# %%
df2_capital = df2_capital.drop(columns = ['순번'])
df2_capital = df2_capital.rename(columns = {'시도본부' : '시도', '119안전센터명' : '119안전센터'})
df2_capital['소방서'] = df2_capital['소방서'] + str('소방서')
df2_capital
# Out:
#      시도    소방서     119안전센터                      주소          전화번호
# 0    서울  종로소방서  세종로119안전센터        서울특별시 종로구 율곡로 78  02-6981-5740
# 1    서울  종로소방서   신교119안전센터       서울특별시 종로구 자하문로 93   02-737-8119
# 2    서울  종로소방서   종로119안전센터       서울특별시 종로구 돈화문로 30   02-747-7119
# 3    서울  종로소방서   연건119안전센터        서울특별시 종로구 대학로 91   02-747-8119
# 4    서울  종로소방서   신영119안전센터       서울특별시 종로구 진흥로 477   02-391-0119
# ..   ..    ...         ...                     ...           ...
# 490  경기  양평소방서   강상119안전센터     경기도 양평군 강상면 송학길 54   031-770-0520
# 491  경기  양평소방서   용문119안전센터      경기도 양평군 용문면 연수로 64  031-770-0530
# 492  경기  양평소방서   양서119안전센터  경기도 양평군 양서면 양수리 1161-4  031-770-0546
# 493  경기  과천소방서   중앙119안전센터          경기도 과천시 통영로 12   02-3314-500
# 494  경기  과천소방서   과천119안전센터           경기도 과천시 궁말로30   02-3314-510
#
# [247 rows x 5 columns]

# %%
df = pd.concat([df1_capital, df2_capital])
df
# Out:
#      시도     소방서                      주소          전화번호    119안전센터
# 0    서울   종로소방서        서울특별시 종로구 율곡로 78  02-6981-5600        NaN
# 1    서울   중부소방서        서울특별시 중구 퇴계로 394  02-2233-1219        NaN
# 2    서울   광진소방서      서울특별시 광진구 광나루로 480  02-6981-6600        NaN
# 3    서울   용산소방서      서울특별시 용산구 한강대로 167  02-6943-1400        NaN
# 4    서울  동대문소방서       서울특별시 동대문구 장한로 34  02-6942-1200        NaN
# ..   ..     ...                     ...           ...        ...
# 490  경기   양평소방서     경기도 양평군 강상면 송학길 54   031-770-0520  강상119안전센터
# 491  경기   양평소방서      경기도 양평군 용문면 연수로 64  031-770-0530  용문119안전센터
# 492  경기   양평소방서  경기도 양평군 양서면 양수리 1161-4  031-770-0546  양서119안전센터
# 493  경기   과천소방서          경기도 과천시 통영로 12   02-3314-500  중앙119안전센터
# 494  경기   과천소방서           경기도 과천시 궁말로30   02-3314-510  과천119안전센터
#
# [296 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# 시도          0
# 소방서         0
# 주소          0
# 전화번호        1
# 119안전센터    49
# dtype: int64

# %%
print(df[df.isna().any(axis=1)])
# Out:
#      시도      소방서                       주소           전화번호    119안전센터
# 0    서울    종로소방서         서울특별시 종로구 율곡로 78   02-6981-5600        NaN
# 1    서울    중부소방서         서울특별시 중구 퇴계로 394   02-2233-1219        NaN
# 2    서울    광진소방서       서울특별시 광진구 광나루로 480   02-6981-6600        NaN
# 3    서울    용산소방서       서울특별시 용산구 한강대로 167   02-6943-1400        NaN
# 4    서울   동대문소방서        서울특별시 동대문구 장한로 34   02-6942-1200        NaN
# 5    서울   영등포소방서       서울특별시 영등포구 문래로 197   02-6981-7000        NaN
# 6    서울    성북소방서      서울특별시 성북구 종암로 27길 3   02-6981-7200        NaN
# 7    서울    은평소방서        서울특별시 은평구 통일로 962   02-6981-6000        NaN
# 8    서울    강남소방서       서울특별시 강남구 테헤란로 629   02-6981-7408        NaN
# 9    서울    서초소방서        서울특별시 서초구 사평대로 67    02-594-0119        NaN
# 10   서울    강서소방서        서울특별시 강서구 양천로 550   02-6981-5000        NaN
# 11   서울    강동소방서         서울특별시 강동구 성내로 39   02-6981-7600        NaN
# 12   서울    마포소방서         서울특별시 마포구 창전로 76   02-6981-7800        NaN
# ...

# %%
df.at[118, '전화번호'] = '02-6981-6479'

# %%
print(df[df.isna().any(axis=1)])
# Out:
#     시도      소방서                       주소           전화번호 119안전센터
# 0   서울    종로소방서         서울특별시 종로구 율곡로 78   02-6981-5600     NaN
# 1   서울    중부소방서         서울특별시 중구 퇴계로 394   02-2233-1219     NaN
# 2   서울    광진소방서       서울특별시 광진구 광나루로 480   02-6981-6600     NaN
# 3   서울    용산소방서       서울특별시 용산구 한강대로 167   02-6943-1400     NaN
# 4   서울   동대문소방서        서울특별시 동대문구 장한로 34   02-6942-1200     NaN
# 5   서울   영등포소방서       서울특별시 영등포구 문래로 197   02-6981-7000     NaN
# 6   서울    성북소방서      서울특별시 성북구 종암로 27길 3   02-6981-7200     NaN
# 7   서울    은평소방서        서울특별시 은평구 통일로 962   02-6981-6000     NaN
# 8   서울    강남소방서       서울특별시 강남구 테헤란로 629   02-6981-7408     NaN
# 9   서울    서초소방서        서울특별시 서초구 사평대로 67    02-594-0119     NaN
# 10  서울    강서소방서        서울특별시 강서구 양천로 550   02-6981-5000     NaN
# 11  서울    강동소방서         서울특별시 강동구 성내로 39   02-6981-7600     NaN
# 12  서울    마포소방서         서울특별시 마포구 창전로 76   02-6981-7800     NaN
# 13  서울    도봉소방서        서울특별시 도봉구 도봉로 666   02-6981-8073     NaN
# ...

# %%
df = df.fillna('소방서')
df
# Out:
#      시도     소방서                      주소          전화번호    119안전센터
# 0    서울   종로소방서        서울특별시 종로구 율곡로 78  02-6981-5600        소방서
# 1    서울   중부소방서        서울특별시 중구 퇴계로 394  02-2233-1219        소방서
# 2    서울   광진소방서      서울특별시 광진구 광나루로 480  02-6981-6600        소방서
# 3    서울   용산소방서      서울특별시 용산구 한강대로 167  02-6943-1400        소방서
# 4    서울  동대문소방서       서울특별시 동대문구 장한로 34  02-6942-1200        소방서
# ..   ..     ...                     ...           ...        ...
# 490  경기   양평소방서     경기도 양평군 강상면 송학길 54   031-770-0520  강상119안전센터
# 491  경기   양평소방서      경기도 양평군 용문면 연수로 64  031-770-0530  용문119안전센터
# 492  경기   양평소방서  경기도 양평군 양서면 양수리 1161-4  031-770-0546  양서119안전센터
# 493  경기   과천소방서          경기도 과천시 통영로 12   02-3314-500  중앙119안전센터
# 494  경기   과천소방서           경기도 과천시 궁말로30   02-3314-510  과천119안전센터
#
# [296 rows x 5 columns]

# %%
print(df[df.isna().any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [시도, 소방서, 주소, 전화번호, 119안전센터]
# Index: []

# %%
from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')

# 위도, 경도 반환하는 함수
def geocoding(address):
    try:
        geo = geo_local.geocode(address)
        x_y = [geo.latitude, geo.longitude]
        return x_y

    except:
        return [0,0]

# %%
geocoding('서울특별시 중구 퇴계로 394(무학동)')
# Out:
# [0, 0]

# %%
geocoding('서울특별시 중구 퇴계로 394')
# Out:
# [37.5649203, 127.01540614808982]

# %%
# 주소를 위,경도 값으로 변환하기
latitude = []
longitude =[]

for i in df['주소']:
    latitude.append(geocoding(i)[0])
    longitude.append(geocoding(i)[1])

# %%
# Dataframe만들기
address_df = pd.DataFrame({'시도' : df['시도'], '소방서' : df['소방서'], '119안전센터' : df['119안전센터'], '주소' : df['주소'], '전화번호' : df['전화번호'], '위도' : latitude, '경도' : longitude})
address_df
# Out:
#      시도     소방서    119안전센터                      주소          전화번호         위도  \
# 0    서울   종로소방서        소방서        서울특별시 종로구 율곡로 78  02-6981-5600  37.576097
# 1    서울   중부소방서        소방서        서울특별시 중구 퇴계로 394  02-2233-1219  37.564920
# 2    서울   광진소방서        소방서      서울특별시 광진구 광나루로 480  02-6981-6600  37.544835
# 3    서울   용산소방서        소방서      서울특별시 용산구 한강대로 167  02-6943-1400  37.536259
# 4    서울  동대문소방서        소방서       서울특별시 동대문구 장한로 34  02-6942-1200  37.568730
# ..   ..     ...        ...                     ...           ...        ...
# 490  경기   양평소방서  강상119안전센터     경기도 양평군 강상면 송학길 54   031-770-0520  37.480290
# 491  경기   양평소방서  용문119안전센터      경기도 양평군 용문면 연수로 64  031-770-0530  37.503033
# 492  경기   양평소방서  양서119안전센터  경기도 양평군 양서면 양수리 1161-4  031-770-0546  37.544791
# 493  경기   과천소방서  중앙119안전센터          경기도 과천시 통영로 12   02-3314-500  37.428566
# 494  경기   과천소방서  과천119안전센터           경기도 과천시 궁말로30   02-3314-510   0.000000
#
#              경도
# 0    127.000136
# 1    127.015406
# ...

# %%
address_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 296 entries, 0 to 494
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   시도       296 non-null    object
#  1   소방서      296 non-null    object
#  2   119안전센터  296 non-null    object
#  3   주소       296 non-null    object
#  4   전화번호     296 non-null    object
#  5   위도       296 non-null    float64
#  6   경도       296 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 26.6+ KB

# %%
address_df.loc[address_df['위도'] == 0]
# Out:
#      시도    소방서     119안전센터                          주소           전화번호   위도  \
# 6    서울  성북소방서         소방서         서울특별시 성북구 종암로 27길 3   02-6981-7200  0.0
# 15   서울  노원소방서         소방서        서울특별시 노원구 한글비석로 1길 8   02-6981-6800  0.0
# 85   경기  화성소방서         소방서        경기도도 화성시 향남읍 향남로 399  031-8012-6100  0.0
# 92   경기  오산소방서         소방서             경기도 오산시 문헌공로 30  031-8059-7100  0.0
# 41   서울  강남소방서   개포119안전센터        서울특별시 강남구 논현로 10길 19    02-577-2540  0.0
# 62   서울  마포소방서   염리119안전센터       서울특별시 마포구 토정로 37길 27     02-713-0965  0.0
# 66   서울  마포소방서   상암119안전센터     서울특별시 마포구 월드컵북로 42길 34     02-309-5119  0.0
# 381  경기  성남소방서   단대119안전센터    경기도 성남시 수정구 논골로 11번길 7-2   031-720-0520  0.0
# 408  경기  안산소방서   선부119안전센터       겅기도 안산시 단원구 선부광장서로 43   031-470-7520  0.0
# 420  경기  용인소방서   남사119안전센터      경기도 용인시 처인구 남사면 봉무로 13  031-8021-0540  0.0
# 422  경기  용인소방서   이동119안전센터  경기도 용인시 처인구 이동면 백옥대로 416-2  031-8021-0560  0.0
# ...

# %%
address_df.at[6, '주소'] = '서울특별시 성북구 종암동 3-72'
address_df.at[15, '주소'] = '서울특별시 노원구 하계동 251-14'
address_df.at[85, '주소'] = '경기도 화성시 향남읍 행정리 436-6'
address_df.at[92, '주소'] = '경기 오산시 내삼미동 880'
address_df.at[41, '주소'] = '서울특별시 강남구 개포동 1197-5'
address_df.at[62, '주소'] = '서울특별시 마포구 염리동 174-19'
address_df.at[66, '주소'] = '서울특별시 마포구 월드컵로42길 34'
address_df.at[381, '주소'] = '경기 성남시 수정구 논골로11번길 7-2'
address_df.at[408, '주소'] = '경기 안산시 단원구 선부광장서로 43'
address_df.at[420, '주소'] = '경기 용인시 처인구 남사읍 봉무로 13'
address_df.at[422, '주소'] = '경기 용인시 처인구 이동읍 백옥대로 416-2'
address_df.at[423, '주소'] = '경기 용인시 기흥구 보정동 1255-1'
address_df.at[426, '주소'] = '경기 용인시 처인구 모현읍 독점로 31-12'
address_df.at[427, '주소'] = '공세동 670-2'
address_df.at[430, '주소'] = '경기 평택시 팽성읍 팽성송화로 172'
address_df.at[431, '주소'] = '만호리 578-3'
address_df.at[437, '주소'] = '경기 평택시 청북읍 현곡산단로 16'
address_df.at[445, '주소'] = '경기 시흥시 장현동 548-5'
address_df.at[458, '주소'] = '경기 이천시 장호원읍 서동대로8829번길 71'
address_df.at[459, '주소'] = '오천리 453'
address_df.at[469, '주소'] = '경기 광주시 오포로 910-5'
address_df.at[471, '주소'] = '경기 광주시 대명대길 30'
address_df.at[476, '주소'] = '칠곡리 928-3'
address_df.at[478, '주소'] = '초이동 623-8'
address_df.at[479, '주소'] = '덕풍동 738'
address_df.at[494, '주소'] = '주암동 685-49'
address_df = address_df.drop([483], axis = 0)

# %%
# 주소를 위,경도 값으로 변환하기
latitude = []
longitude =[]

for i in address_df['주소']:
    latitude.append(geocoding(i)[0])
    longitude.append(geocoding(i)[1])

# %%
# Dataframe만들기
address_df = pd.DataFrame({'시도' : address_df['시도'], '소방서' : address_df['소방서'], '119안전센터' : address_df['119안전센터'], '주소' : address_df['주소'], '전화번호' : address_df['전화번호'], '위도' : latitude, '경도' : longitude})
address_df
# Out:
#      시도     소방서    119안전센터                      주소          전화번호         위도  \
# 0    서울   종로소방서        소방서        서울특별시 종로구 율곡로 78  02-6981-5600  37.576097
# 1    서울   중부소방서        소방서        서울특별시 중구 퇴계로 394  02-2233-1219  37.564920
# 2    서울   광진소방서        소방서      서울특별시 광진구 광나루로 480  02-6981-6600  37.544835
# 3    서울   용산소방서        소방서      서울특별시 용산구 한강대로 167  02-6943-1400  37.536259
# 4    서울  동대문소방서        소방서       서울특별시 동대문구 장한로 34  02-6942-1200  37.568730
# ..   ..     ...        ...                     ...           ...        ...
# 490  경기   양평소방서  강상119안전센터     경기도 양평군 강상면 송학길 54   031-770-0520  37.480290
# 491  경기   양평소방서  용문119안전센터      경기도 양평군 용문면 연수로 64  031-770-0530  37.503033
# 492  경기   양평소방서  양서119안전센터  경기도 양평군 양서면 양수리 1161-4  031-770-0546  37.544791
# 493  경기   과천소방서  중앙119안전센터          경기도 과천시 통영로 12   02-3314-500  37.428566
# 494  경기   과천소방서  과천119안전센터              주암동 685-49   02-3314-510  37.451587
#
#              경도
# 0    127.000136
# 1    127.015406
# ...

# %%
address_df.loc[address_df['위도'] == 0]
# Out:
# Empty DataFrame
# Columns: [시도, 소방서, 119안전센터, 주소, 전화번호, 위도, 경도]
# Index: []

# %%
address_df.to_csv('address_df.csv', encoding = 'utf-8-sig')

# %%
import folium
import pandas as pd

# %%
df = pd.read_csv('address_df.csv', encoding = 'utf-8-sig')
df
# Out:
#      Unnamed: 0  시도     소방서    119안전센터                      주소          전화번호  \
# 0             0  서울   종로소방서        소방서        서울특별시 종로구 율곡로 78  02-6981-5600
# 1             1  서울   중부소방서        소방서        서울특별시 중구 퇴계로 394  02-2233-1219
# 2             2  서울   광진소방서        소방서      서울특별시 광진구 광나루로 480  02-6981-6600
# 3             3  서울   용산소방서        소방서      서울특별시 용산구 한강대로 167  02-6943-1400
# 4             4  서울  동대문소방서        소방서       서울특별시 동대문구 장한로 34  02-6942-1200
# ..          ...  ..     ...        ...                     ...           ...
# 290         490  경기   양평소방서  강상119안전센터     경기도 양평군 강상면 송학길 54   031-770-0520
# 291         491  경기   양평소방서  용문119안전센터      경기도 양평군 용문면 연수로 64  031-770-0530
# 292         492  경기   양평소방서  양서119안전센터  경기도 양평군 양서면 양수리 1161-4  031-770-0546
# 293         493  경기   과천소방서  중앙119안전센터          경기도 과천시 통영로 12   02-3314-500
# 294         494  경기   과천소방서  과천119안전센터              주암동 685-49   02-3314-510
#
#             위도          경도
# ...

# %%
import requests
import json

# 서울 행정구역 json raw파일(githubcontent)
r = requests.get('https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json')
c = r.content
seoul_geo = json.loads(c)

# %%
m = folium.Map(
    location=[37.559819, 126.963895],
    zoom_start=11, 
)

folium.GeoJson(
    seoul_geo,
    name='지역구'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd
import folium
 
seoul_map = folium.Map(location=[37.559819, 126.963895], zoom_start=10)
 
for i in range(len(address_df)):
    folium.Marker([address_df.iloc[i][4], address_df.iloc[i][5]], popup=address_df.전화번호[i]).add_to(seoul_map)
 
seoul_map.save('seoul.html')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\DMC CONET\AppData\Local\Programs\Python\Python39\lib\site-packages\folium\utilities.py:69, in validate_location(location)
#      68 try:
# ---> 69     float(coord)
#      70 except (TypeError, ValueError):
#
# ValueError: could not convert string to float: '02-6981-5600'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 7
#       4 seoul_map = folium.Map(location=[37.559819, 126.963895], zoom_start=10)
#       6 for i in range(len(address_df)):
# ----> 7     folium.Marker([address_df.iloc[i][4], address_df.iloc[i][5]], popup=address_df.전화번호[i]).add_to(seoul_map)
#       9 seoul_map.save('seoul.html')
#
# ...

# %%
m = folium.Map(location=[latitude, longitude],
               zoom_start=17, 
               width=750, 
               height=500
              )
m
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\DMC CONET\AppData\Local\Programs\Python\Python39\lib\site-packages\folium\utilities.py:69, in validate_location(location)
#      68 try:
# ---> 69     float(coord)
#      70 except (TypeError, ValueError):
#
# TypeError: float() argument must be a string or a number, not 'list'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 m = folium.Map(location=[latitude, longitude],
#       2                zoom_start=17,
#       3                width=750,
#       4                height=500
#       5               )
#       6 m
#
# ...

# %%
#data = {'이름' : '은평소방서', '전화번호' : '010-123-123'}
popup = folium.Popup('이름 : 은평소방서, 전화번호 : 010-123-123', max_width=650)
folium.Marker([latitude, longitude],
              popup= popup,
              tooltip="은평소방서",
              #icon=folium.Icon('red', icon='star')
              ).add_to(m),
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
