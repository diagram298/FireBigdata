# %%
import pandas as pd
b1 = pd.read_csv('best1.csv')
b2 = pd.read_csv('best2.csv')

# %%
list_reason = b1.drop_duplicates(subset=['reason']).reason.tolist()

# %%
list_reason
# Out:
# ['변전실',
#  '변압기',
#  '화재 원인',
#  '화목난로',
#  '화목 난로의 연통이 과열',
#  '연기흡입',
#  '담뱃갑과 담배꽁초',
#  '정확한 화재 원인',
#  '전기장판',
#  '전기적 요인',
#  '부주의',
#  '고양이',
#  '성묘객 실화',
#  '화재 원인과 재산 피해',
#  '합동 감식을 통해 정확한 화재 원인',
#  '담배꽁초 등 부주의',
#  '가정집 화재로 혼자 있던 50대 남성 질식사 21일 오후 6시께 서울 성북구 정릉동의 한 1층짜리 주택 방 안에서 50대 남성이 숨진 채 발견됐다. 숨진 A(52)씨가 발견된 방 안에는 전기장판 등 집기에 화재가 발생한 흔적이 있었으나 창문이 닫혀 있어 크게 번지지는 않았다. 소방당국에 따르면 연락이 닿지 않아 집을 방문한 가족이 숨진 A씨를 발견해 신고했으며, 출동 당시 불은 꺼진 상태였다. 경찰은 A씨가 질식해 숨진 것으로 추정하고 사망 경위를 확인하기 위해 부검을 할 방침이다. 또 소방당국과 함께 정확한 화재 원인',
#  '정전기',
#  '연기',
#  '실화',
# ...

# %%
new_list_reason = []
for i in list_reason:
    if len(i) < 20:
        new_list_reason.append(i)
new_list_reason# .sort(key=len)
# Out:
# ['변전실',
#  '변압기',
#  '화재 원인',
#  '화목난로',
#  '화목 난로의 연통이 과열',
#  '연기흡입',
#  '담뱃갑과 담배꽁초',
#  '정확한 화재 원인',
#  '전기장판',
#  '전기적 요인',
#  '부주의',
#  '고양이',
#  '성묘객 실화',
#  '화재 원인과 재산 피해',
#  '합동 감식을 통해 정확한 화재 원인',
#  '담배꽁초 등 부주의',
#  '정전기',
#  '연기',
#  '실화',
#  '배터리 문제',
#  '랜턴 배터리가 과열',
#  '난로',
#  '성묘객의 실수',
#  '재산피해',
#  '부부가 살던 집 안방',
#  '배터리 결함',
#  '집 안방',
#  '짧고 강한 연소',
#  '매장 내부',
#  '화재 원인과 피해 규모',
#  '발화 지점',
#  '민가 인근 농지',
#  '연통이 과열',
#  '불티',
#  '쓰레기 소각',
#  '부탄가스',
#  '배터리 셀 제조 불량',
#  '담배꽁초나 쓰레기 소각 등 부주의',
#  '전했',
#  '공사장 전기 작업',
#  '배터리셀 불량',
#  '배터리셀 제조불량 내부합선',
#  '배터리 셀 제조불량',
#  '검은 연기',
#  '사고 발생의 정확한 원인',
#  '객실 내 담뱃불 부주의',
#  '방화',
#  '창고 전선',
#  '입산자 실화',
#  '재활용품 정리 장소',
#  '쓰레기를 태우다 불이 번진 것',
#  '전기합선',
#  '가스폭발',
#  '공장 기계 쪽',
#  '마당 내 폐기물 더미',
#  '전기난로와 우레탄 폼',
#  '전기 합선',
#  '벼락',
#  '콘센트 과부하',
#  '비어있는 객실',
#  '누전',
#  '현장 조사',
#  '붕괴',
#  '발화',
#  '주택화재',
#  '4',
#  '처리능력 초과',
#  '않',
#  '가연성 소재',
#  '화상',
#  '잔열',
#  '용접 중 불티',
#  '전기배선 오작동',
#  '쓰레기를 소각',
# ...

# %%
len(new_list_reason)
# Out:
# 317

# %%
print(len(list_reason), len(new_list_reason))
# Out:
# 379 317
