# %%
from NER import  NerFactory

# %%
import torch, gc
gc.collect()
torch.cuda.empty_cache()

# %%
ner = NerFactory()

# %%
sentence  =  [ "이태원 참사·제2경인고속도로 화재 연결시킨 서영교…“尹정부 사건사고 끊이질 않아”", "2022 화정 아이파크 붕괴사고 그 이후"]
for title in sentence :
    result = ner.get_entities(title)
    print(result, "\n")
# Out:
# [{'code': 'EV', 'word': '이태원 참사'}, {'code': 'AF', 'word': '제2경인고속도로'}, {'code': 'PS', 'word': '서영교'}, {'code': 'OG', 'word': '정부'}]
#
# [{'code': 'DT', 'word': '2022'}, {'code': 'EV', 'word': '화정 아이파크 붕괴사고'}]

# %%
import pandas as pd 
df = pd.read_excel("/home/intern2/fire_dev/NEWS_NLP/NewsResult_20220101-20221231.xlsx")
df.info()
# Out:
# /home/intern2/anaconda3/envs/Pororo/lib/python3.7/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   뉴스 식별자             20000 non-null  float64
#  1   일자                 20000 non-null  int64
#  2   언론사                20000 non-null  object
#  3   기고자                19418 non-null  object
#  4   제목                 20000 non-null  object
#  5   통합 분류1             20000 non-null  object
#  6   통합 분류2             17929 non-null  object
#  7   통합 분류3             13571 non-null  object
#  8   사건/사고 분류1          10072 non-null  object
#  9   사건/사고 분류2          2729 non-null   object
#  10  사건/사고 분류3          680 non-null    object
# ...

# %%
sentence = df['제목'][:500].tolist()

# %%
for title in sentence :
    result = ner.get_entities(title)
    print("제목", title)
    print(result, "\n")
# Out:
# 제목 [단독] 신분당선 판교역-정자역 사이에서 멈췄다 승객들 큰 혼란 “이러다 죽는 거 아니야?”
# [{'code': 'AF', 'word': '신분당선'}, {'code': 'LC', 'word': '판교역'}, {'code': 'LC', 'word': '정자역'}]
#
# 제목 후배에게 흉기 휘둘러 숨지게 한 50대 남성 긴급체포
# [{'code': 'QT', 'word': '50대'}]
#
# 제목 '깨알 증거 공개' 한동훈 공수처 고발...처벌 가능성은?
# [{'code': 'PS', 'word': '한동훈'}, {'code': 'OG', 'word': '공수처'}]
#
# 제목 '몰카 피해자인데 ' 남친 찾아가 항의한 여성, 되레 벌금형
# []
#
# 제목 [영상] 아듀! 2022 강원 10대 영상 뉴스
# [{'code': 'DT', 'word': '2022'}, {'code': 'LC', 'word': '강원'}, {'code': 'QT', 'word': '10대'}]
#
# 제목 다사다난했던 경남 되돌아본 2022년
# [{'code': 'LC', 'word': '경남'}]
#
# 제목 방음 터널 사망자 5명 신원 확인..."당분간 터널 통제"
# [{'code': 'QT', 'word': '5명'}]
#
# 제목 산 채로 땅속에 묻힌 푸들 '생매장 혐의' 견주 최후는
# [{'code': 'AM', 'word': '푸들'}]
#
# 제목 경찰, 군산 주택 방화 용의자 붙잡아 조사
# [{'code': 'OG', 'word': '경찰'}, {'code': 'LC', 'word': '군산'}]
#
# 제목 찜질방 가던 모녀도 ‘터널 화재’ 사망자 5명 신원 확인(종합)
# [{'code': 'CV', 'word': '모녀'}, {'code': 'QT', 'word': '5명'}]
#
# 제목 갈 길 먼 진상 규명 ‘윗선’ 수사 공전
# [{'code': 'TM', 'word': '윗선'}]
#
# ...
