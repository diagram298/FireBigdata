# %%
import pandas as pd

# %%
df = pd.read_csv("Final_fire_news_6.csv", encoding = 'utf-8')
df
# Out:
#                         _id       send_timestamp  \
# 0      AKR20221231041400061  2022-12-31T23:20:59
# 1      AKR20221231035000099  2022-12-31T18:08:13
# 2      AKR20221230074600052  2022-12-31T10:00:05
# 3      AKR20221230074600052  2022-12-31T10:00:05
# 4      AKR20221230139200004  2022-12-31T10:00:04
# ...                     ...                  ...
# 14052  PYH20220701172200004  2022-07-01T16:35:00
# 14053  AKR20220701074553004  2022-07-01T15:56:12
# 14054  AKR20220701074552004  2022-07-01T14:50:21
# 14055  AKR20220701074551004  2022-07-01T12:05:09
# 14056  AKR20220701074500004  2022-07-01T11:26:40
#
#                                 Title  \
# 0      신분당선 판교∼정자역 사이서 전동차 멈춰1시간가량 불편
# 1          남아공 가스트럭 폭발사고 사망자 34명으로 늘어
# 2       탈선 후 1년째 휴장애물단지 된 통영 욕지도 모노레일
# 3       탈선 후 1년째 휴장애물단지 된 통영 욕지도 모노레일
# 4             오세훈 안전에 모든 노력동행 매력도시 도약
# ...                               ...
# 14052    종로 르메이에르빌딩 5분간 흔들1천여 명 한때 대피
# 14053     종로 르메이에르빌딩 5분간 흔들1천여명 한때 대피
# ...

# %%
df.columns.tolist()
# Out:
# ['_id',
#  'send_timestamp',
#  'Title',
#  'Body',
#  'YNewsML.Metadata.Region.RegionCode',
#  'Summarization',
#  'NamedEntity',
#  'Keyword',
#  'img_link',
#  'issue_word',
#  'reason',
#  'class_code',
#  'class_name',
#  'Issue',
#  'Main_news_id']

# %%
df['Issue'].value_counts()
# Out:
# 이태원압사참사         924
# 태풍 힌남노          417
# 봉화 광산사고         238
# 대전 현대아울렛 화재     181
# SPC 공장 사고       154
# 제2경인 방음터널 화재     79
# 이천 빌딩화재          54
# 화일약품 공장 폭발       48
# 안성 추락사고          44
# 지하철 3호선 화재       40
# 종로 르메이에르 빌딩      19
# Name: Issue, dtype: int64

# %%
df['Main_news_id'].value_counts()
# Out:
# False    14041
# True        16
# Name: Main_news_id, dtype: int64

# %%
df['Body'][0]
# Out:
# '이영주 기자 = 31일 오후 9시 40분께 경기도 성남시 신분당선 판교역과 정자역 사이 선로에서 전동차가 고장으로 멈춰 섰다. 열차가 승강장이 아닌 선로에서 멈추는 바람에 승객들은 한 시간가량 전동차 안에서 후속 조치를 기다리는 등 큰 불편을 겪어야 했다. 당시 전동차에 탑승했던 승객 등에 따르면 전동차 내부를 비추는 불이 한때 꺼졌다가 다시 들어오기도 한 것으로 전해졌다. 고장 열차는 1시간 5분만인 이날 오후 10시 45분께 후속 구원열차의 도움으로 정자역으로 이동할 수 있었다. 신분당선 운영사 관계자는 내일 중 전동차가 고장 난 이유를 조사할 예정이라고 말했다. young86@'
