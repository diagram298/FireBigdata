# %%
from pororo import Pororo

# %%
import pandas as pd

# %%
from bertopic import BERTopic

# %%
topic_model = BERTopic.load("best_model")

# %%
list1 = pd.DataFrame(topic_model.representative_docs_).T[0].tolist()

# %%
zsl = Pororo(task="zero-topic",lang='ko')
# Out:
#   2% [.                                                                     ]   5455872 / 205792658
#   8% [.....                                                                 ]  17620992 / 205792658
#  14% [..........                                                            ]  30285824 / 205792658
#  20% [..............                                                        ]  41918464 / 205792658
#  27% [..................                                                    ]  55607296 / 205792658
#  33% [.......................                                               ]  68050944 / 205792658
#  39% [...........................                                           ]  81256448 / 205792658
#  44% [...............................                                       ]  92340224 / 205792658
#  51% [....................................                                  ] 106635264 / 205792658
# ...

# %%
df = pd.read_csv('only_acc_code1.csv',encoding='utf-8-sig')

# %%
d1 = pd.DataFrame(pd.DataFrame(df['words']).value_counts()).reset_index()

# %%
word = d1[d1[0] > 2]['words'].tolist()

# %%
word.append('상관없음')

# %%
word
# Out:
# ['이태원 참사',
#  '이태원 압사 참사',
#  '이태원 사고',
#  '이태원참사',
#  '이태원',
#  '10·29 이태원참사',
#  '세월호 참사',
#  '49재',
#  '학동참사',
#  '10',
#  '참사',
#  '이태원 참사 희생자 추모 위령제',
#  '압사 참사',
#  '이태원참사 사고',
#  '용산 이태원 참사',
#  '10.29(이태원) 참사 희생자 추모 위령제',
#  '이태원 참사 시민 추모 촛불 : 당신 잘못이 아닙니다',
#  '재난대응 안전한국훈련',
#  '세월호',
#  '불꽃축제',
#  '이태원 핼러',
#  '수능',
#  '재난 대응 안전한국훈련',
#  '세월호 침몰',
#  '여의도 불꽃축제',
#  '우크라이나 전쟁',
#  '대선',
#  '지방선거',
#  '러브 퍼레이드',
#  '핼러윈 축제',
#  '핼러',
#  '화정',
#  '10·29 이태원 참사',
#  '5·18',
#  '10·29 참사',
#  '학동 참사',
#  '학동 붕괴 참사',
#  '수산대축제',
#  'Bon Om Touk',
#  '화정아이파크 붕괴사고',
#  '세월호 사고',
#  '테크노 음악 축제',
#  '유대교 축제',
#  '우면산 산사태',
#  '한국전쟁',
#  '동일본대지진',
#  '프로축구',
#  '이프 카카오',
#  '잉글랜드축구협회',
#  '태원 참사',
#  '본 옴 뚝',
#  '직원 한마음 워크숍',
#  '재난대응 안전한국',
#  '후쿠시마 원전 사고',
#  '부산불꽃축제',
#  '상관없음']

# %%
j = df['title'].tolist()

# %%
result = []
for i in j:
    a = zsl(i,['이태원 압사 참사','이태원이 아닌 사건'])
    result.append([i,a])

# %%
result1 = []
for i in range(len(result)):
    if result[i][1]['이태원 압사 참사'] > result[i][1]['이태원이 아닌 사건']:
        result1.append([result[i][0],'이태원 압사 참사'])
    else:
        result1.append([result[i][0],'이태원이 아닌 사건'])

# %%
pd.DataFrame(result1).to_csv('zero-shot.csv',encoding='utf-8-sig',index=False)
